# %% [markdown]
# [<img src="scktblogo.png" align = 'left'>](http://scikit-rf.readthedocs.org/en/latest/)

# %% [markdown]
# # Linux [Installation](http://scikit-rf.readthedocs.org/en/latest/tutorials/installation.html)

# %%
%%bash
easy_install scikit-rf
# Out:
# Searching for scikit-rf
# Best match: scikit-rf 0.14
# Processing scikit_rf-0.14-py2.7.egg
# scikit-rf 0.14 is already the active version in easy-install.pth
#
# Using /home/kranzi/anaconda/lib/python2.7/site-packages/scikit_rf-0.14-py2.7.egg
# Processing dependencies for scikit-rf
# Finished processing dependencies for scikit-rf

# %% [markdown]
# # Getting Started

# %% [markdown]
# Plot touchstone data on a smith chart, in **3 lines**.

# %%
import skrf as rf
#
ntwk = rf.Network( '4p7_Code_00.S2P' )
ntwk.plot_s_smith()

# %% [markdown]
# #[Examples](http://nbviewer.ipython.org/github/scikit-rf/examples/blob/master/index.ipynb)
#
# Below are examples which demonstrate some applications of scikit-rf. They are written in the form of ipython notebooks.
#
# ##[Time Domain Analysis](http://nbviewer.ipython.org/github/scikit-rf/examples/blob/master/Time%20Domain.ipynb)
# ###[Quick Example](http://nbviewer.ipython.org/github/scikit-rf/examples/blob/master/Time%20Domain.ipynb#Quick-Example)

# %%
import skrf as rf
#
probe = rf.Network( 'oneport_tiered_calibration/probe.s2p' )
probe.plot_s_db_time()

# %% [markdown]
# ###[Time Domain](http://nbviewer.ipython.org/github/scikit-rf/examples/blob/master/Time%20Domain.ipynb#Time-Domain)
#
# Plotting the Network in both frequency and time-domain

# %%
# plot frequency and time-domain s-parameters
figure( figsize = ( 8, 4 ) )
#
subplot( 121 )
probe.plot_s_db()
title( 'Frequency Domain' )
#
subplot( 122 )
probe.plot_s_db_time()
title( 'Time Domain' )
#
tight_layout()

# %%
probe.plot_s_db( 0, 0 )
title( 'Reflection Coefficient From \nWaveguide Port' )

# %%
probe.plot_s_db_time( 0,0 )
title( 'Reflection Coefficient From \nWaveguide Port, Time Domain' )
ylim( -100, 0 )
# Out:
# (-100, 0)

# %% [markdown]
# ###[Determining Distance](http://nbviewer.ipython.org/github/scikit-rf/examples/blob/master/Time%20Domain.ipynb#Determining-Distance)

# %%
from skrf.media import RectangularWaveguide
cm = 1e-2
# create a rectangular waveguide media to gererate a theoretical network
wr1p5 = RectangularWaveguide( frequency = probe.frequency, 
                              a = 15 * rf.mil, z0 = 1 ) 
# create an ideal delayed load, parameters are adjusted until the
# theoretical response agrees with the measurement
theory = wr1p5.delay_load( Gamma0 = rf.db_2_mag( -20 ),
                           d = 2.4 * cm )
probe.plot_s_db_time( 0, 0, label = 'Measurement' )
theory.plot_s_db_time( label = '-20dB @ 2.4cm from test-port' )
ylim( -100, 0 )
# Out:
# (-100, 0)

# %%
probe_w = probe.windowed()
probe.plot_s_db( 0, 0, label = 'Original' )
probe_w.plot_s_db( 0, 0, label = 'Windowed' )

# %%
probe.plot_s_time_db(   0, 0, label = "Original" )
probe_w.plot_s_time_db( 0, 0, label = "Windowed" )

# %% [markdown]
# ###[Formating Junk](http://nbviewer.ipython.org/github/scikit-rf/examples/blob/master/Time%20Domain.ipynb#Formating-junk)

# %%
from IPython.core.display import HTML
#
def css_styling():
    styles = open("./styles/plotly.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     /*body {
#         background-color: #F5F5F5;
#     }*/
#     div.cell{
#         width: 850px;
#         margin-left: 10% !important;
#         margin-right: auto;
#     }
#     h1 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
#     }
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 40pt;
#         line-height: 100%;
#         color:#447adb;
#         margin-bottom: 0em;
#         margin-top: 0em;
#         display: block;
#         white-space: nowrap;
#     }
#     h2 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
#
#     }
#     .text_cell_render h2 {
#         font-weight: 200;
#         font-size: 20pt;
#
#         line-height: 100%;
#         color:#447adb;
#         margin-bottom: 1.5em;
#         margin-top: 0.5em;
#         display: block;
#         white-space: nowrap;
#     }
#     h3 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
#     }
#     .text_cell_render h3 {
# ...
