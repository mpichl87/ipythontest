# %%
Pkg.add( "PyPlot" )
# Out:
# INFO: Updating cache of PyPlot...
# INFO: Installing Color v0.3.15
# INFO: Installing Dates v0.3.2
# INFO: Installing FixedPointNumbers v0.0.6
# INFO: Installing LaTeXStrings v0.1.2
# INFO: Installing PyCall v0.7.3
# INFO: Installing PyPlot v1.5.0
# INFO: Package database updated
# INFO: METADATA is out-of-date — you may not have the latest version of PyPlot
# INFO: Use `Pkg.update()` to get the latest versions of your packages

# %%
Pkg.update()
# Out:
# INFO: Updating METADATA...
# INFO: Computing changes...
# INFO: No packages to install, update or remove

# %%
Pkg.status()
# Out:
# 2 required packages:
#  - IJulia                        0.1.16
#  - PyPlot                        1.5.0
# 13 additional packages:
#  - BinDeps                       0.3.7
#  - Color                         0.3.15
#  - Compat                        0.2.6
#  - Dates                         0.3.2
#  - FixedPointNumbers             0.0.6
#  - JSON                          0.4.0
#  - LaTeXStrings                  0.1.2
#  - Nettle                        0.1.7
#  - PyCall                        0.7.3
#  - REPLCompletions               0.0.3
#  - SHA                           0.0.3
#  - URIParser                     0.0.3
#  - ZMQ                           0.1.15

# %%
using PyPlot
x = linspace( 0, 2π, 1000 )
y = sin( 3x + 4cos( 2x ) )
plot( x, y, color = "red", linewidth = 2.0, linestyle = "--" )
title( "A sinusoidally modulated sinusoid" )
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f029c933bd0>)
# PyObject <matplotlib.text.Text object at 0x7f027f556210>

# %%
PyPlot.svg( true );

# %%
using PyPlot
x = linspace( 0, 2π, 1000 )
y = sin( 3x + 4cos( 2x ) )
plot( x, y, color = "red", linewidth = 2.0, linestyle = "--" )
title( "A sinusoidally modulated sinusoid" )
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f027f248c90>)
# PyObject <matplotlib.text.Text object at 0x7f027f096f10>
