# %% [markdown]
# # [PyCall](https://github.com/stevengj/PyCall.jl)

# %% [markdown]
# ## Installation

# %%
Pkg.add("PyCall")
# Out:
# INFO: No packages to install, update or remove
# INFO: Package database updated

# %% [markdown]
# ## Usage

# %%
using PyCall
@pyimport math
math.sin( math.pi / 4 ) - sin( pi / 4 )  # returns 0.0
# Out:
# 0.0

# %%
using PyCall
using PyPlot
@pyimport skrf as sk
ntwk = sk.Network( "4p7_Code_00.S2P" )
ntwk[ :plot_s_smith ]()
# Out:
# INFO: Loading help data...
# Figure(PyObject <matplotlib.figure.Figure object at 0x7ffb4a9a0210>)
